# %% [markdown]
# <a href="https://colab.research.google.com/github/tranquocdienspkt/AIspkt/blob/main/W9_31_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


x = test_images
y = test_labels

digit = train_images[500]

plt.imshow(digit, cmap = plt.cm.binary)

plt.show()

print(train_labels[500])
# Out:
# 3

# %%
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.tight_layout()
  plt.imshow(train_images[i], cmap = 'gray', interpolation='none')
  plt.title("So: {}".format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(512, activation = 'relu', input_shape = (784,)))

model.add(Dense(10, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 512)               401920
#
#  dense_8 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images = train_images.reshape(60000,28*28)
train_images = train_images.astype('float32')/255

test_images = test_images.reshape(10000,28*28)
test_images = test_images.astype('float32')/255

# %%
from keras.utils import  to_categorical

train_labels = to_categorical(train_labels,10)
test_labels = to_categorical(test_labels,10)

# %%
model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])

model.fit(train_images, train_labels, epochs=10, batch_size=128)

test_loss, test_acc = model.evaluate(test_images, test_labels)

print('Mat mat: ', test_loss)
print('Do chinh xac: ', test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 5s 9ms/step - loss: 2.9767e-04 - accuracy: 1.0000
# Epoch 2/10
# 469/469 [==============================] - 5s 11ms/step - loss: 2.6088e-04 - accuracy: 1.0000
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 2.3838e-04 - accuracy: 1.0000
# Epoch 4/10
# 469/469 [==============================] - 4s 9ms/step - loss: 2.1807e-04 - accuracy: 1.0000
# Epoch 5/10
# 469/469 [==============================] - 5s 11ms/step - loss: 2.0132e-04 - accuracy: 1.0000
# Epoch 6/10
# 469/469 [==============================] - 4s 9ms/step - loss: 1.8700e-04 - accuracy: 1.0000
# Epoch 7/10
# 469/469 [==============================] - 4s 9ms/step - loss: 1.7717e-04 - accuracy: 1.0000
# Epoch 8/10
# 469/469 [==============================] - 5s 10ms/step - loss: 1.6533e-04 - accuracy: 1.0000
# Epoch 9/10
# 469/469 [==============================] - 4s 9ms/step - loss: 1.5604e-04 - accuracy: 1.0000
# Epoch 10/10
# ...

# %%
import numpy as np

img = x[4567]
plt.imshow(img)
plt.show()


X_pred = x[4567].reshape(1,28*28)

X_pred = X_pred.astype('float32')/255

np.argmax(model.predict(X_pred), axis = -1)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# array([4])

# %%
from keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# for i in range(10):
#   Z = x_train[i]
#   plt.imshow(Z)
#   plt.show()

model1 = Sequential()
model1.add(Dense(1000, activation = 'relu', input_shape = (3072,)))

model1.add(Dense(10, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 512)               401920
#
#  dense_8 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# (50000, 32, 32, 3)

# %%
x_train = x_train.reshape(50000,32*32*3)
x_train = x_train.astype('float32')/255

x_test = x_test.reshape(10000,32*32*3)
x_test = x_test.astype('float32')/255

# %%
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %%
model1.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])

model1.fit(x_train, y_train, epochs=10, batch_size=128)

test_loss1, test_acc1 = model1.evaluate(x_test, y_test)



print('Mat mat: ', test_loss1)
print('Do chinh xac: ', test_acc1)
# Out:
# Epoch 1/10
# 391/391 [==============================] - 20s 50ms/step - loss: 2.3302 - accuracy: 0.2667
# Epoch 2/10
# 391/391 [==============================] - 21s 53ms/step - loss: 1.7873 - accuracy: 0.3612
# Epoch 3/10
# 391/391 [==============================] - 20s 50ms/step - loss: 1.6977 - accuracy: 0.3953
# Epoch 4/10
# 391/391 [==============================] - 20s 52ms/step - loss: 1.6424 - accuracy: 0.4180
# Epoch 5/10
# 391/391 [==============================] - 22s 55ms/step - loss: 1.6014 - accuracy: 0.4296
# Epoch 6/10
# 391/391 [==============================] - 20s 50ms/step - loss: 1.5691 - accuracy: 0.4455
# Epoch 7/10
# 391/391 [==============================] - 21s 54ms/step - loss: 1.5434 - accuracy: 0.4533
# Epoch 8/10
# 391/391 [==============================] - 20s 51ms/step - loss: 1.5194 - accuracy: 0.4613
# Epoch 9/10
# 391/391 [==============================] - 21s 53ms/step - loss: 1.4940 - accuracy: 0.4725
# Epoch 10/10
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5b1a537e-288f-43f6-94dd-4c7f6a6d6457" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5b1a537e-288f-43f6-94dd-4c7f6a6d6457">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from keras.utils import load_img, img_to_array

url = 'dog1.jpg'

img = plt.imread(url)
plt.imshow(img)
plt.show()

img = load_img(url, target_size=(32,32))
plt.imshow(img)

img = img_to_array(img)
img = img.reshape(1,32*32*3)
img = img.astype('float32')/255


np.argmax(model1.predict(img), axis = -1)
# Out:
# 1/1 [==============================] - 0s 44ms/step
# array([2])
