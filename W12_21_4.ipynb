# %% [markdown]
# <a href="https://colab.research.google.com/github/tranquocdienspkt/AIspkt/blob/main/W12_21_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# pip install youtube-search
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from youtube_search import YoutubeSearch
import webbrowser
from openpyxl import Workbook
data = Workbook()
sheet = data.active
mysong=input('Moi ban chon ten bai hat: ')
print(mysong)
result = YoutubeSearch(mysong, max_results=10).to_dict()
print(result)
for i in range(10):
  print(result[i]['title'])
  print(result[i]['url_suffix'])
  url = 'https://www.youtube.com' + result[i]['url_suffix']
  print(url)
  sheet['A'+str(i+1)]=i+1
  sheet['B'+str(i+1)]=result[i]['title']
  sheet['C'+str(i+1)]=result[i]['url_suffix']
  sheet['D'+str(i+1)]=result[i]['views']

data.save('UEH.xlsx')
# Out:
# Moi ban chon ten bai hat: Nơi tình yêu bắt đầu
# Nơi tình yêu bắt đầu
# ...

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 23.1 MB/s eta 0:00:00
# ...

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt

filename = 'asf.jpg'
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 4/4 [==============================] - 0s 62ms/step
# {'box': [357, 360, 155, 208], 'confidence': 0.9999999403953552, 'keypoints': {'left_eye': (403, 432), 'right_eye': (473, 434), 'nose': (440, 477), 'mouth_left': (401, 502), 'mouth_right': (474, 503)}}
# {'box': [63, 55, 158, 208], 'confidence': 0.9999997019767761, 'keypoints': {'left_eye': (100, 135), 'right_eye': (177, 133), 'nose': (136, 171), 'mouth_left': (100, 201), 'mouth_right': (182, 201)}}
# {'box': [72, 948, 159, 221], 'confidence': 0.9999992251396179, 'keypoints': {'left_eye': (104, 1035), 'right_eye': (174, 1036), 'nose': (128, 1079), 'mouth_left': (105, 1112), 'mouth_right': (175, 1116)}}
# {'box': [669, 949, 158, 212], 'confidence': 0.9999974370002747, 'keypoints': {'left_eye': (723, 1035), 'right_eye': (797, 1036), 'nose': (770, 1079), 'mouth_left': (726, 1106), 'mouth_right': (794, 1106)}}
# ...

# %%
filename = '/content/chup-nhom-nho.jpg'
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 2/2 [==============================] - 0s 30ms/step
# {'box': [225, 120, 94, 127], 'confidence': 0.9999966025352478, 'keypoints': {'left_eye': (255, 166), 'right_eye': (298, 179), 'nose': (268, 204), 'mouth_left': (242, 207), 'mouth_right': (286, 219)}}
# {'box': [481, 74, 78, 104], 'confidence': 0.9999915957450867, 'keypoints': {'left_eye': (500, 117), 'right_eye': (535, 112), 'nose': (519, 132), 'mouth_left': (504, 151), 'mouth_right': (542, 146)}}
# {'box': [335, 116, 113, 141], 'confidence': 0.9999493956565857, 'keypoints': {'left_eye': (365, 175), 'right_eye': (410, 157), 'nose': (396, 194), 'mouth_left': (385, 222), 'mouth_right': (430, 204)}}
# {'box': [56, 117, 128, 153], 'confidence': 0.9998331069946289, 'keypoints': {'left_eye': (109, 163), 'right_eye': (165, 189), 'nose': (133, 198), 'mouth_left': (86, 214), 'mouth_right': (144, 239)}}
# ...

# %%
from textwrap import fill
filename = '/content/chup-nhom-nho.jpg'
img = plt.imread(filename)
plt.imshow(img)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x, y, width, height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color = 'red')
  ax.add_patch(rect)
  # plt.savefig("face.png")

  for key, value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color = 'red')
    ax.add_patch(dot)
  # plt.savefig("face1.png")
plt.show()
# Out:
# ...
# 2/2 [==============================] - 0s 21ms/step

# %%
def draw_faces(filename, result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1, y1, width, height = result_list[i]['box']
    x2, y2 = x1 + width, y1 + height
    plt.subplot(1, len(result_list), i + 1)
    plt.savefig(f'faceh{i}.jpg')
    plt.axis('off')
    plt.imshow(data[y1:y2, x1:x2])
    
plt.show()

filename = '/content/chup-nhom-nho.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename, faces)
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fbbfac41e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 145ms/step
# ...

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted: [('n01871265', 'tusker', 0.6093754), ('n02504458', 'African_elephant', 0.37518835), ('n02504013', 'Indian_elephant', 0.015435094)]

# %%
import tensorflow as tf

model = tf.keras.applications.vgg16.VGG16(
    include_top=True,
    weights='imagenet',
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classes=1000,
    classifier_activation='softmax'
)

img_path = '/content/elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
print(decode_predictions(preds, top=5))
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[('n01871265', 'tusker', 0.66071415), ('n02504458', 'African_elephant', 0.265134), ('n02504013', 'Indian_elephant', 0.07413799), ('n02408429', 'water_buffalo', 5.768445e-06), ('n01704323', 'triceratops', 4.754184e-06)]]
